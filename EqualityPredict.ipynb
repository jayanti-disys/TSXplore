# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


if __name__ == "__main__":
    
    df = pd.read_csv("/Users/jayanti/Data/BSE/PERSISTANT.csv")
    
    print(df.shape, df.columns)

    S = pd.Series (index = df['Date'].to_list(), data=df['Close Price'].to_list())
    
    fig = plt.figure (figsize=(18,6))
    ax = fig.add_subplot(111)
    ax.plot(S)
    plt.show()
# Out:
# (2745, 13) Index(['Date', 'Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP',
#        'No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
#        'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
#        'Spread Close-Open'],
#       dtype='object')
